# %%
# !pip install -U pyopenssl cryptography
# Out:
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)

# %%
pip install cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\asus\anaconda3\lib\site-packages)

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
from bson import Binary
import gridfs
from PIL import Image

# %%
client = MongoClient("mongodb://localhost:27017")

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client["templates_resume"]

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'templates_resume')

# %%
fs = gridfs.GridFS(db)

# %%
fs

# %%
from pymongo import MongoClient
import base64

# %%
collection = db['resumes']

# %%
from PIL import Image

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 1.png",)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=989x1400 at 0x13A58E4DAF0>

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 2.png",)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=989x1400 at 0x13A590EC610>

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 3.png",)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=989x1400 at 0x13A590ECD00>

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 4.png",)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=989x1400 at 0x13A590EC2E0>

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 5.png",)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=989x1400 at 0x13A57182520>

# %%
image = Image.open("C:\\Users\\asus\\Downloads\\template 6.png",)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=989x1400 at 0x13A58EA77F0>

# %%
client = MongoClient("mongodb://localhost:27017")
db = client["templates_resume"]
fs = gridfs.GridFS(db)
with open("C:\\Users\\asus\\Downloads\\template 1.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 2.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 1.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 3.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 4.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 5.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
with open("C:\\Users\\asus\\Downloads\\template 6.png", "rb") as image_file:
    image_data = image_file.read()
    binary_data = Binary(image_data)
image_id = fs.put(binary_data, filename="image.jpg")
image_id = fs.put(binary_data, filename="image.jpg")
retrieved_image = fs.get(image_id)
with open("retrieved_image.png", "wb") as output_file:
    output_file.write(retrieved_image.read())
retrieved_image = fs.get(image_id)
with open("retrieved_image.png", "wb") as output_file:
    output_file.write(retrieved_image.read())

# %%
client.close()
